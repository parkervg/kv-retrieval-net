# %%
from google.colab import drive 
drive.mount('/content/drive') 
# %cd "drive/MyDrive/kv-retrieval-net"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/kv-retrieval-net'
# /content/drive/MyDrive/kv-retrieval-net

# %%
# !pip install torch
# !pip install transformers
# !pip install sacrebleu
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (4.2.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.18.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.12.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.53)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: sacrebleu in /usr/local/lib/python3.7/dist-packages (2.0.0)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.8.9)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2019.12.20)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (2.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (1.21.6)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from sacrebleu) (0.4.4)

# %%
from typing import Union

import attr
import torch
from attr import attrib
from torch.utils.data import DataLoader
from pathlib import Path
import pickle

from src.model import *
from src.prepare_data import KVRETDataset
from src.utils import utils
import nltk
nltk.download('punkt')

@attr.s
class Args:
    kvret_path: str = attrib()
    model_name: str = attrib()
    include_context: bool = attrib(default=True)
    reverse_input: bool = attrib(default=False)
    epochs: int = attrib(default=10)
    embed_size: int = attrib(default=300)
    hidden_size: int = attrib(default=768)
    num_layers: int = attrib(default=1)
    max_length: Union[int, str] = attrib(default=32)
    lr: float = attrib(default=0.0001)
    weight_decay: float = attrib(default=0)
    batch_size: int = attrib(default=32)
    dropout: float = attrib(default=0.1)
    attention_type: str = attrib(default="bahdanau")
    weight_decay: float = attrib(default=0)
    grad_clip: float = attrib(default=10.0)
    model_save_dir: str = attrib(default="models/")
    teacher_forcing_ratio: float = attrib(default=0.5)
    use_pretrained: bool = attrib(default=False)
    device: torch.device = attrib(default=torch.device("cpu"))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
MODEL_NAME = "bahdanau_base_no_glove"
args = Args(kvret_path="data/kvret_dataset_public/kvret_{}_public.json", model_name=MODEL_NAME)
#####################################################################################################################
args.epochs = 50
args.embed_size = 200
args.hidden_size = 200
args.teacher_forcing_ratio = 0.7
args.lr = 0.001
args.max_length = "longest"
args.attention_type = "bahdanau"
args.use_pretrained = False
args.dropout = 0.3
args.batch_size = 32
args.num_layers = 1
args.include_context = True
args.reverse_input = True
args.device = (
    torch.device("cpu") if not torch.cuda.is_available() else torch.device("cuda")
)
#####################################################################################################################
print(f"Running on {args.device}...")
dataset = KVRETDataset(
        train_path=args.kvret_path.format("train"),
        dev_path=args.kvret_path.format("dev"),
        test_path=args.kvret_path.format("test"),
        device=args.device,
        include_context=args.include_context,
        max_len=args.max_length,
        reverse_input=args.reverse_input,
    )
eos_token_id = dataset.tok2id["[EOS]"]
sos_token_id = dataset.tok2id["[SOS]"]
pad_id = dataset.tok2id["[PAD]"]

train_dataloader = DataLoader(dataset.train, batch_size=args.batch_size, shuffle=True)
dev_dataloader = DataLoader(dataset.dev, batch_size=args.batch_size, shuffle=True)
test_dataloader = DataLoader(dataset.test, batch_size=args.batch_size, shuffle=True)
if args.use_pretrained:
    pretrained_weights = utils.get_pretrained_weights(
        args.embed_size, dataset.tok2id
    )
else:
    pretrained_weights = None

model = KVNetwork(
    num_vocab=len(dataset.id2tok),
    embed_size=args.embed_size,
    hidden_size=args.hidden_size,
    dropout=args.dropout,
    device=args.device,
    num_layers=args.num_layers,
    padding_idx=pad_id,
    kb_vocab_start=dataset.kb_vocab_start,
    attention_type=args.attention_type,
    pretrained_weights=pretrained_weights,
)
model.to(args.device)

optimizer = torch.optim.Adam(model.parameters(), lr=args.lr)
criterion = nn.CrossEntropyLoss()
best_model = model
best_bleu = 0
for epoch in range(args.epochs):
    print(f"EPOCH {epoch}")
    print("___________________________________________________________________")
    epoch_loss = 0
    num_correct = num_tokens = 0
    model.train()
    for idx, item in enumerate(train_dataloader):
        outputs = model(
            item=item,
            teacher_forcing_ratio=args.teacher_forcing_ratio,
            sos_token_id=sos_token_id,
        )  # (batch_size, num_vocab, max_len)

        # Loss, but with input_mask
        # also, do not consider [SOS] token in loss
        masked_model_output = (
            outputs * item.get("input_mask").unsqueeze(1).expand_as(outputs)
        )[:, :, 1:]
        masked_gold_output = (item.get("output") * item.get("input_mask"))[:, 1:]
        loss = criterion(masked_model_output, masked_gold_output)
        epoch_loss += loss
        preds = outputs.argmax(1)  # (batch_size, seq_len)
        num_correct += (
            (preds == item.get("output")) * item.get("input_mask")
        ).sum()
        num_tokens += item.get("input_mask").sum()

        model.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), args.grad_clip)
        optimizer.step()
        del loss
    acc = num_correct.item() / num_tokens.item()
    print()
    print(
        " Training Loss: {:.2f} \t Token-level Accuracy: {:.3f}".format(
            epoch_loss, acc
        )
    )
    print()
    print("***********************************************************")
    utils.print_results(
        inputs=item.get("input"),
        outputs=outputs,
        gold=item.get("output"),
        id2tok=dataset.id2tok,
        eos_token_id=eos_token_id,
        reversed=args.reverse_input,
        k=1,
    )
    print("Evaluating on dev set...")
    evaluate_output = utils.evaluate(model=model,
                    dataloader=dev_dataloader,
                    sos_token_id=sos_token_id,
                    eos_token_id=eos_token_id,
                    id2tok=dataset.id2tok)
    print(
        " Token-level Accuracy: {:.3f} \t BLEU: {}".format(
            evaluate_output.get("acc"), evaluate_output.get("bleu")
        )
    )
    print()
    for i in range(5):
      print("\t")
      print(f"Reference: {evaluate_output.get('references')[i]}")
      print(f"Hypothesis: {evaluate_output.get('hypotheses')[i]}")
      print("\n\n")
    if evaluate_output.get("bleu") > best_bleu:
      best_bleu = evaluate_output.get("bleu")
      print(f"New best bleu score! {best_bleu}")
      best_model = model

print("Evaluating best model on test set...")
evaluate_output = utils.evaluate(model=best_model,
                    dataloader=test_dataloader,
                    sos_token_id=sos_token_id,
                    eos_token_id=eos_token_id,
                    id2tok=dataset.id2tok)
print(
    " Token-level Accuracy: {:.3f} \t BLEU: {}".format(
        evaluate_output.get("acc"), evaluate_output.get("bleu")
    )
)
print(f"Saving model to {args.model_save_dir}...")
# Save relevant .pkl files
model_save_dir = Path(args.model_save_dir) / args.model_name 
model_save_dir.mkdir(parents=True)
torch.save(best_model.state_dict(), model_save_dir / "model.pt")
dataset.test.device = torch.device("cpu")
with open(model_save_dir / "dataset.pkl", "wb") as f:
    pickle.dump(dataset.test, f)
# Out:
# Running on cuda...
# Padding to 90...
# Padding to 97...
# Padding to 49...
# using bahdanau attention...
# EPOCH 0
# ___________________________________________________________________
#
#  Training Loss: 1504.80 	 Token-level Accuracy: 0.204
#
# ***********************************************************
# Input:
#
# set a reminder about the meeting at 4 pm this week with the sales team, to discuss the company picnic
#
# Output:
#
# what are the meeting to reminder reminder meeting for for?
#
# Expected:
#
# okay, scheduling a a reminder about the meeting at 4 pm this week with the sales team, to discuss the company picnic
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.217 	 BLEU: 1.7080102004105377
#
#
# Reference: the address for coupa is coupa_address
# Hypothesis: you're welcome.
#
#
#
#
# Reference: for what city do you need information about today's forecast?
# Hypothesis: what city are you like to know the weather for?
#
#
#
#
# Reference: philz is 5672_barringer_street_distance away at philz_addressnue. anything else?
# Hypothesis: you're welcome!
#
#
#
#
# Reference: there isn't any traffic, heading to starbucks_address
# Hypothesis: navigation is located away away.
#
#
#
#
# Reference: okay, when should i schedule it?
# Hypothesis: what are you like to know the?
#
#
#
# New best bleu score! 1.7080102004105377
# EPOCH 1
# ___________________________________________________________________
#
#  Training Loss: 1467.91 	 Token-level Accuracy: 0.305
#
# ***********************************************************
# Input:
#
# is there a nearby the_westin_poi_type? * hotel_keen and the_westin are both nearby. * which has the least amount of traffic at the moment. * they both have none. * what is the address for keen?
#
# Output:
#
# the address is the route to be the address of and is.
#
# Expected:
#
# hotel_keen_address, we're the_westin_distance away from it. set the navigation there?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.239 	 BLEU: 3.1909589394112032
#
#
# Reference: in the next week in san_francisco it will be dry on monday, raining on tuesday, hail on wednesday and thursday, hot on friday, overcast on saturday, frost on sunday
# Hypothesis: the forecast for is the forecast for the forecast for the next week.
#
#
#
#
# Reference: the weather in new_york is hot today. are you interested in other days' forecast?
# Hypothesis: what city are you interested in?
#
#
#
#
# Reference: it will not be windy in new_york city tomorrow.
# Hypothesis: no problem.
#
#
#
#
# Reference: is there anything else i can do for you?
# Hypothesis: you are welcome.
#
#
#
#
# Reference: there is pizza_my_heart pizza_my_heart_distance away: is it okay for you?
# Hypothesis: there is a jacks_house_address away.
#
#
#
# New best bleu score! 3.1909589394112032
# EPOCH 2
# ___________________________________________________________________
#
#  Training Loss: 1462.28 	 Token-level Accuracy: 0.327
#
# ***********************************************************
# Input:
#
# what is the date and time i should take my medicine?
#
# Output:
#
# your have three scheduled medicine medicine. medicine at the. pm, the other one the at 10.
#
# Expected:
#
# you have two medicine events scheduled. one on taking_medicine_date at taking_medicine_time and the other on taking_medicine_date at optometrist_appointment_time.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.245 	 BLEU: 4.1561297106460815
#
#
# Reference: setting gps to quickest route for jing_jing which has jing_jing_traffic_info.
# Hypothesis: the closest is town_and_country_address away.
#
#
#
#
# Reference: okay, adding playing tennis to your calendar, on august the 8th at 10 am.
# Hypothesis: i have scheduled scheduled for your appointment.
#
#
#
#
# Reference: no problem.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: there is no snow forecasted for chicago this week.
# Hypothesis: it will not be in in this week.
#
#
#
#
# Reference: trader_joes is at trader_joes_address. the only route i have is trader_joes_distance through trader_joes_traffic_info
# Hypothesis: the address is palo_alto_medical_foundation_address.
#
#
#
# New best bleu score! 4.1561297106460815
# EPOCH 3
# ___________________________________________________________________
#
#  Training Loss: 1455.88 	 Token-level Accuracy: 0.356
#
# ***********************************************************
# Input:
#
# i think i have a friend who lives around here, what is their address, and find me the quickest route there * jill's house is jills_house_distance away at jills_house_address. would you like directions there? * yes please. * setting navigation now. there is a round_table_traffic_info, so please drive carefully. * thank you.
#
# Output:
#
# you're welcome
#
# Expected:
#
# you're welcome!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.244 	 BLEU: 4.80765652096007
#
#
# Reference: your tennis_activity is on dentist_appointment_date at 11am.
# Hypothesis: your next is tennis at 3pm.
#
#
#
#
# Reference: there is two stanford_shopping_center_poi_type, town_and_country and stanford_shopping_center. do you have a preference?
# Hypothesis: the nearest is stanford_shopping_center_address away.
#
#
#
#
# Reference: happy to help
# Hypothesis: you're welcome!
#
#
#
#
# Reference: your lab_appointment is scheduled on lab_appointment_date at 4 pm.
# Hypothesis: your lab_appointment is on yoga_activity_date at yoga_activity_time.
#
#
#
#
# Reference: glad i could help out
# Hypothesis: you're welcome!
#
#
#
# New best bleu score! 4.80765652096007
# EPOCH 4
# ___________________________________________________________________
#
#  Training Loss: 1454.87 	 Token-level Accuracy: 0.361
#
# ***********************************************************
# Input:
#
# please tell me about the time and date my next meeting is scheduled for and what i hope to accomplish it * your next meeting is meeting_date at 10am. its purpose is to meeting_agenda. * where is the location of the meeting?
#
# Output:
#
# the purpose meeting to is meeting_date at purpose.
#
# Expected:
#
# the location is the meeting_room.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.253 	 BLEU: 6.2692625319348245
#
#
# Reference: you're welcome.
# Hypothesis: you are welcome.
#
#
#
#
# Reference: you're welcome!
# Hypothesis: anytime!
#
#
#
#
# Reference: what city should i check the weekly temperature for?
# Hypothesis: what city are you wanting to know about?
#
#
#
#
# Reference: over the next 7 days the days with the highest temperature will be wednesday and friday with a high of 90f.
# Hypothesis: the highest temperature in oakland will be 100f on monday and a high of 100f
#
#
#
#
# Reference: since there is a valero_traffic_info, i found another route for you and i sent it on your screen
# Hypothesis: there is palo_alto_garage_r_distance palo_alto_garage_r_distance away palo_alto_garage_r_distance, i sent it on your screen, drive carefully!
#
#
#
# New best bleu score! 6.2692625319348245
# EPOCH 5
# ___________________________________________________________________
#
#  Training Loss: 1451.91 	 Token-level Accuracy: 0.375
#
# ***********************************************************
# Input:
#
# set reminder for eye doctor appointment on the 12th at 3 pm
#
# Output:
#
# reminder set your reminder for 3pm appointment at 3 eye on pm.
#
# Expected:
#
# i have set a reminder for your 3 pm eye doctor appointment on the 12th.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.261 	 BLEU: 6.419807153517313
#
#
# Reference: the football game is at tennis_activity_time.
# Hypothesis: what city would you like the weather for?
#
#
#
#
# Reference: setting directions to peets_coffee at peets_coffee_address. now.
# Hypothesis: peets_coffee_address is located at peets_coffee_address peets_coffee_address.
#
#
#
#
# Reference: what days are you inquiring about?
# Hypothesis: what city would you like the weather forecast for?
#
#
#
#
# Reference: palo_alto_medical_foundation is the nearest palo_alto_medical_foundation_poi_type at palo_alto_medical_foundation_address.
# Hypothesis: home_poi_type is at jills_house_address.
#
#
#
#
# Reference: the weather in san_francisco during the next week will be humid on monday, clear skies on tuesday, stormy on wednesday, raining on thursday, windy on friday, raining again on saturday and sunday
# Hypothesis: what city are you interested in?
#
#
#
# New best bleu score! 6.419807153517313
# EPOCH 6
# ___________________________________________________________________
#
#  Training Loss: 1449.76 	 Token-level Accuracy: 0.389
#
# ***********************************************************
# Input:
#
# are there jing_jing_poi_types nearby
#
# Output:
#
# you is a couple on, would
#
# Expected:
#
# there is a jing_jing nearby.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.255 	 BLEU: 6.680678436910363
#
#
# Reference: no, panda_express is the only one i have listed.
# Hypothesis: there is trader_joes_poi_type trader_joes_poi_type but it is that away and there is 5677_springer_street_traffic_info on our way
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: no problem.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: it's not gonna rain in fresno this week
# Hypothesis: it will not be rain in fresno this week.
#
#
#
# New best bleu score! 6.680678436910363
# EPOCH 7
# ___________________________________________________________________
#
#  Training Loss: 1448.19 	 Token-level Accuracy: 0.396
#
# ***********************************************************
# Input:
#
# where is the closest place to eat * you can pick between the pizzeria pizza_my_heart and the p.f._changs_poi_type p.f._changs, they're both p.f._changs_distance away * i think i want pizza tonight, can you give me directions? * pizza_my_heart is located at pizza_my_heart_address * give me the quickest route please. * here is the quickest route to pizza_my_heart. * thank you!
#
# Output:
#
# you're welcome.
#
# Expected:
#
# you're welcome!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.266 	 BLEU: 7.913456976391733
#
#
# Reference: you're very welcome.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: you are welcome driver.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: where is the location?
# Hypothesis: okay, i am for a dentist pm on the calendar at 7pm.
#
#
#
#
# Reference: sure! do you want me to schedule it for tomorrow?
# Hypothesis: okay, scheduling a yoga activity with your sister for the 12th at 1pm.
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you're welcome.
#
#
#
# New best bleu score! 7.913456976391733
# EPOCH 8
# ___________________________________________________________________
#
#  Training Loss: 1449.08 	 Token-level Accuracy: 0.390
#
# ***********************************************************
# Input:
#
# please give me the address and directions by a route with four_seasons_traffic_info to a dominos_poi_type near me. * the nearest pizza place is dominos at dominos_address but a road block is being reported. * ugh okay well find me the quickest route please.
#
# Output:
#
# dominos is dominos_distance away at dominos_address.
#
# Expected:
#
# the route to dominos dominos_distance away is the quickest one that i can find
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.257 	 BLEU: 9.070492655594649
#
#
# Reference: current schedule is empty
# Hypothesis: ok, i am scheduling a dentist appointment with your appointment at 10am.
#
#
#
#
# Reference: the low temperature for menlo_park on monday is 90f with a high of 100f, it will be unk warm
# Hypothesis: it will not be warm in menlo_park on monday.
#
#
#
#
# Reference: there is coupa, it's just coupa_distance away but there is home_traffic_info on our way
# Hypothesis: there is chevron_traffic_info chevron_traffic_info coffee and philz.
#
#
#
#
# Reference: two unk are located nearby. one is the topanga_mall located topanga_mall_distance away and the other is ravenswood_shopping_center that's ravenswood_shopping_center_distance away. which do you prefer?
# Hypothesis: ravenswood_shopping_center is ravenswood_shopping_center_distance away.
#
#
#
#
# Reference: setting gps now.
# Hypothesis: the address is trader_joes, i sent it on your screen, drive carefully!
#
#
#
# New best bleu score! 9.070492655594649
# EPOCH 9
# ___________________________________________________________________
#
#  Training Loss: 1446.90 	 Token-level Accuracy: 0.401
#
# ***********************************************************
# Input:
#
# i want tea.
#
# Output:
#
# there have a listings listings tea couple away is tea is is that away.
#
# Expected:
#
# i have a location for a place that serves tea that is 5677_springer_street_distance away. you need more info?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.264 	 BLEU: 8.316467839881454
#
#
# Reference: starbucks is at starbucks_address.
# Hypothesis: the address is 5672_barringer_street_distance away, i sent it on your screen
#
#
#
#
# Reference: there is no starbucks nearby, the palo_alto_cafe is palo_alto_cafe_distance away. would you like directions there?
# Hypothesis: there nearest starbucks is starbucks nearby.
#
#
#
#
# Reference: you're welcome
# Hypothesis: anytime.
#
#
#
#
# Reference: it will not be misty on friday in exeter.
# Hypothesis: it will not be exeter in exeter on exeter.
#
#
#
#
# Reference: you're welcome.
# Hypothesis: the is located at the_westin_address, it's the_westin_distance, it's just expected to go, it's minutes
#
#
#
# EPOCH 10
# ___________________________________________________________________
#
#  Training Loss: 1445.00 	 Token-level Accuracy: 0.415
#
# ***********************************************************
# Input:
#
# show me what time i need to take my pills * you need to take your medicine at medicine_time. * thank you.
#
# Output:
#
# you are welcome.
#
# Expected:
#
# you are welcome.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.258 	 BLEU: 9.546325450373752
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: is there a date or time for dinner that i should add to this reminder?
# Hypothesis: what date and time would you like to set the reminder?
#
#
#
#
# Reference: p.f._changs has palo_alto_cafe_traffic_info at the moment. i am setting the navigation and we should arrive soon.
# Hypothesis: setting a reminder for your lab appointment with marie on the route.
#
#
#
#
# Reference: your tennis_activity is scheduled for 11am on meeting_date, nothing is scheduled for saturday.
# Hypothesis: your tennis_activity is at match at 3pm.
#
#
#
#
# Reference: yes the route to palo_alto_medical_foundation_address is the quickest available.
# Hypothesis: the address is palo_alto_medical_foundation, i sent it on your screen
#
#
#
# New best bleu score! 9.546325450373752
# EPOCH 11
# ___________________________________________________________________
#
#  Training Loss: 1443.77 	 Token-level Accuracy: 0.417
#
# ***********************************************************
# Input:
#
# schedule a reminder for a doctor appointment with my father on august 22nd at 10am * okay, setting a reminder for your doctor's appointment on august the 22nd at 10 am with your father. * thank you.
#
# Output:
#
# you are
#
# Expected:
#
# you are welcome.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.254 	 BLEU: 7.621475107190322
#
#
# Reference: it will be 50f sunday in oakland.
# Hypothesis: the lowest temperature in oakland is 90f, and a high of 90f.
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you are welcome
#
#
#
#
# Reference: you're welcome; drive safely, and enjoy.
# Hypothesis: you're welcome; drive carefully.
#
#
#
#
# Reference: glad to help
# Hypothesis: you are welcome.
#
#
#
#
# Reference: you're welcome, gps set and you should arrive shortly.
# Hypothesis: you're welcome.
#
#
#
# EPOCH 12
# ___________________________________________________________________
#
#  Training Loss: 1443.66 	 Token-level Accuracy: 0.422
#
# ***********************************************************
# Input:
#
# what is the time and date of my doctors appointment? * you have 3 appointments in your calendar. one on doctor_appointment_date at oplab_appointment_partyetrist_appointment_time, one on doctor_appointment_date at oplab_appointment_partyetrist_appointment_time, and one on doctor_appointment_date at lab_appointment_time. * okay, thanks.
#
# Output:
#
# glad to welcome help.
#
# Expected:
#
# glad i could help.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.263 	 BLEU: 8.833298093003094
#
#
# Reference: panda_express is a panda_express_poi_type nearby.
# Hypothesis: there is a mandarin_roots sigona_farmers_market_distance away.
#
#
#
#
# Reference: anytime!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: your reminder is set.
# Hypothesis: what time is your lab appointment?
#
#
#
#
# Reference: you're welcome.
# Hypothesis: you are welcome.
#
#
#
#
# Reference: i have four, one with optometrist_appointment_party at optometrist_appointment_time on optometrist_appointment_date, one with your optometrist_appointment_party at optometrist_appointment_time on optometrist_appointment_date, one with optometrist_appointment_party on optometrist_appointment_date, and one with optometrist_appointment_party on optometrist_appointment_date. which one?
# Hypothesis: your optometrist_appointment is optometrist_appointment_date at optometrist_appointment_time with optometrist_appointment_party.
#
#
#
# EPOCH 13
# ___________________________________________________________________
#
#  Training Loss: 1442.28 	 Token-level Accuracy: 0.429
#
# ***********************************************************
# Input:
#
# what is the weather going to be today and tomorrow
#
# Output:
#
# which location do you want the weather forecast for?
#
# Expected:
#
# what city would you like the weather for?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.264 	 BLEU: 8.689484393350483
#
#
# Reference: okay, scheduling a dinner with your father for monday the 1st at 4pm.
# Hypothesis: okay, i am scheduling a dinner on the 1st at 11am with your father.
#
#
#
#
# Reference: sure, it's just jing_jing_distance away at the_clement_hotel_addressnue.
# Hypothesis: the quickest route to palo_alto_cafe_address.
#
#
#
#
# Reference: jills_house_address. is the address.
# Hypothesis: jill lives at pizza_chicago_address.
#
#
#
#
# Reference: okay, i have scheduled your dentist appointment for this friday at 10 am with your father. anything else i can help with?
# Hypothesis: your optometrist appointment on your father is at 10 am.
#
#
#
#
# Reference: there currently are no clear skies in redwood_city.
# Hypothesis: there will be no drizzle in redwood_city.
#
#
#
# EPOCH 14
# ___________________________________________________________________
#
#  Training Loss: 1441.24 	 Token-level Accuracy: 0.438
#
# ***********************************************************
# Input:
#
# navigate to the nearest mall
#
# Output:
#
# the are midtown_shopping_center_distance away from stanford_shopping_center and do you like me go there?
#
# Expected:
#
# we are midtown_shopping_center_distance away from midtown_shopping_center: would you like to go there?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.253 	 BLEU: 9.477410597925042
#
#
# Reference: no problem
# Hypothesis: you are welcome.
#
#
#
#
# Reference: is there anything else i can do for you?
# Hypothesis: you doctor appointment doctor's appointment doctor tomorrow eye doctor's appointment
#
#
#
#
# Reference: we are safeway_distance away from safeway with mandarin_roots_traffic_info on our way and safeway_distance away from trader_joes with the_westin_traffic_info: where would you like to go?
# Hypothesis: the is is away at the_westin_address at the_westin_address. at the_westin_address. do round_table_traffic_info?
#
#
#
#
# Reference: no problem.
# Hypothesis: you are welcome.
#
#
#
#
# Reference: danville does not have any dry weather prediction this week.
# Hypothesis: it will not be foggy in danville this week.
#
#
#
# EPOCH 15
# ___________________________________________________________________
#
#  Training Loss: 1437.77 	 Token-level Accuracy: 0.460
#
# ***********************************************************
# Input:
#
# where is the nearest pizza place?
#
# Output:
#
# the is pizza place is pizza_my_heart which round_table_distance away.
#
# Expected:
#
# the nearest pizza place is round_table located round_table_distance away. do you want the address?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.259 	 BLEU: 9.681151118965289
#
#
# Reference: you're welcome
# Hypothesis: you're welcome
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: panda_express is located at panda_express_address
# Hypothesis: yes, it is trader_joes_address to get 5677_springer_street_traffic_info to get 5677_springer_street_traffic_info to get to get 5677_springer_street_traffic_info to get there is 5677_springer_street_traffic_info 5677_springer_street_traffic_info route.
#
#
#
#
# Reference: this week in new_york will be rainy and windy with overcast skies.
# Hypothesis: what city are you in?
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome, have a great day.
#
#
#
# New best bleu score! 9.681151118965289
# EPOCH 16
# ___________________________________________________________________
#
#  Training Loss: 1441.02 	 Token-level Accuracy: 0.438
#
# ***********************************************************
# Input:
#
# where's the nearest place to get lunch * there is tai_pan restaurant tai_pan_distance away with stanford_shopping_center_traffic_info on our way * can i have the address?
#
# Output:
#
# the is it address for trader_joes_address. i way's name it the away
#
# Expected:
#
# sure, the address is tai_pan_address, the restaurant's name is tai_pan
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.264 	 BLEU: 8.58722026494081
#
#
# Reference: you're welcome
# Hypothesis: you're welcome
#
#
#
#
# Reference: okay making appointment with alex on wednesday at 1pm.
# Hypothesis: setting a reminder for your doctor appointment on wednesday at 1pm with alex.
#
#
#
#
# Reference: the weather in san_francisco during the next week will be humid on monday, clear skies on tuesday, stormy on wednesday, raining on thursday, windy on friday, raining again on saturday and sunday
# Hypothesis: it will be overcast on monday and tuesday in san_francisco.
#
#
#
#
# Reference: of course.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: in san_mateo, it will be 50-60f on monday, 30-50f on tuesday, 50-60f on wednesday, 50-70f on thursday, 80-100f on friday, 70-90f on saturday, and 80-100f on sunday.
# Hypothesis: the low temperature in san_jose is 90f, and low of 70f and high of 90f, low of 70f, and high of 90f, low of 90f, and high of 90f, low of 90f, and high of 90f, and a high of 100f on thursday, low of 90f, and high of 90f, low of 90f, and high of 90f, and a high of 100f on thursday, low of 90f, and high of 90f, low of 90f, and high of 90f,
#
#
#
# EPOCH 17
# ___________________________________________________________________
#
#  Training Loss: 1441.14 	 Token-level Accuracy: 0.435
#
# ***********************************************************
# Input:
#
# when's my next scheduled yoga class
#
# Output:
#
# okay next yoga is yoga_activity_date at yoga_activity_time. dinner_date.
#
# Expected:
#
# your next yoga class is at 1pm on yoga_activity_date.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.259 	 BLEU: 9.323397617730667
#
#
# Reference: only dominos is here and there is town_and_country_traffic_info.
# Hypothesis: the is pizza is round_table pizza restaurant is dominos_distance away and there is dominos_distance away and there is dominos_distance away.
#
#
#
#
# Reference: setting a reminder to take my medicine on monday aug 8 at 7 pm with your mother
# Hypothesis: okay, setting a reminder for your dinner appointment at 7 pm on the 8th with mother.
#
#
#
#
# Reference: mandarin_roots is jills_house_distance away in coupa_traffic_info, it is located at mandarin_roots_address.
# Hypothesis: the address is panda_express.
#
#
#
#
# Reference: it will be cloudy in atherton on thursday.
# Hypothesis: thursday will be thursday in thursday in thursday
#
#
#
#
# Reference: you have three yoga activities scheduled. one with yoga_activity_party, your yoga_activity_party, and your yoga_activity_party.
# Hypothesis: you have two yoga activities scheduled. one on doctor_appointment_date with doctor_appointment_party, and one with doctor_appointment_party at yoga_activity_time with doctor_appointment_party.
#
#
#
# EPOCH 18
# ___________________________________________________________________
#
#  Training Loss: 1441.38 	 Token-level Accuracy: 0.435
#
# ***********************************************************
# Input:
#
# schedule meeting.
#
# Output:
#
# what time is your meeting?
#
# Expected:
#
# what details shall i add to your meeting reminder?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.251 	 BLEU: 8.802236390236756
#
#
# Reference: what day and time is the meeting?
# Hypothesis: okay, meeting a meeting scheduled for 1pm today at 1pm.
#
#
#
#
# Reference: p.f._changs has palo_alto_cafe_traffic_info at the moment. i am setting the navigation and we should arrive soon.
# Hypothesis: the're welcome, have a great day.
#
#
#
#
# Reference: your dentist_appointment is at dentist_appointment_time on dentist_appointment_date
# Hypothesis: your dentist_appointment is on dentist_appointment_date at dentist_appointment_time.
#
#
#
#
# Reference: the 76 is located at 76_address; it is 76_distance away in round_table_traffic_info.
# Hypothesis: chevron is at topanga_mall_address.
#
#
#
#
# Reference: jill's house is located at jills_house_address. anything else?
# Hypothesis: your friend is at home_poi_type_address.
#
#
#
# EPOCH 19
# ___________________________________________________________________
#
#  Training Loss: 1436.98 	 Token-level Accuracy: 0.465
#
# ***********************************************************
# Input:
#
# what are the directions to the mall * there is town_and_country town_and_country_distance away: would you like to go there? * yes, please. * navigating to town_and_country. * give me the address.
#
# Output:
#
# town_and_country is located at town_and_country_address town_and_country_distance
#
# Expected:
#
# town_and_country is located at town_and_country_addressnue.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.264 	 BLEU: 9.79418525627286
#
#
# Reference: comfort_inn route is reporting a 76_traffic_info. do you still want to go there?
# Hypothesis: the is is only palo_alto_garage_r_poi_type palo_alto_garage_r_address palo_alto_garage_r_address palo_alto_garage_r_address it palo_alto_garage_r_address with
#
#
#
#
# Reference: it will be windy with a low of 90f and a high of 100f in oakland today.
# Hypothesis: it is 80-90f to be cloudy in oakland on tuesday.
#
#
#
#
# Reference: what city are you interested in?
# Hypothesis: what city do you need the weather for?
#
#
#
#
# Reference: you are welcome.
# Hypothesis: glad to help
#
#
#
#
# Reference: the fastest route to the stanford_childrens_health_poi_type is stanford_childrens_health_address. at pizza_hut_distance away with a pizza_hut_traffic_info. do you want to go to stanford_childrens_health?
# Hypothesis: palo_alto_cafe_address is palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address palo_alto_cafe_address
#
#
#
# New best bleu score! 9.79418525627286
# EPOCH 20
# ___________________________________________________________________
#
#  Training Loss: 1439.30 	 Token-level Accuracy: 0.449
#
# ***********************************************************
# Input:
#
# what time do i have to take my medicine and who will be here?
#
# Output:
#
# your at at tennis_activity_date at at at conference_agenda medicine medicine at time will will be attending. at
#
# Expected:
#
# 5 pm is the time scheduled to take your medicine and your dentist_appointment_party will be there.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.251 	 BLEU: 8.67407686768705
#
#
# Reference: your sister has been added to parties involved for your yoga activity at 2pm on the 1st.
# Hypothesis: i set the gps for your activity with your sister.
#
#
#
#
# Reference: panda_express is a panda_express_poi_type nearby.
# Hypothesis: there is a chef_chu's jacks_house_distance away named chef_chu's trader_joes_address.
#
#
#
#
# Reference: i have two, one at optometrist_appointment_time with optometrist_appointment_party, and one at optometrist_appointment_time with optometrist_appointment_party.
# Hypothesis: you have two football tennis_activity_date tennis_activity_date at tennis_activity_date with tennis_activity_date at tennis_activity_date with tennis_activity_date at tennis_activity_date with your doctor_appointment_party.
#
#
#
#
# Reference: that is still the closest chevron_poi_type.
# Hypothesis: i have a route to avoid the quickest.
#
#
#
#
# Reference: no rain is in the forecast for fresno this week.
# Hypothesis: it will not be raining in fresno this week.
#
#
#
# EPOCH 21
# ___________________________________________________________________
#
#  Training Loss: 1438.10 	 Token-level Accuracy: 0.459
#
# ***********************************************************
# Input:
#
# what palo_alto_medical_foundation_poi_types are here? * palo_alto_medical_foundation is palo_alto_medical_foundation_distance away. * is the traffic bad to get there? * there is palo_alto_medical_foundation_traffic_info on the way to palo_alto_medical_foundation * ok sounds good. set the gps for there please. * gps set, anything else? * what's the address of the location please? * the address for palo_alto_medical_foundation is palo_alto_medical_foundation_address. * ok thanks for all the help.
#
# Output:
#
# you gps welcome. gps gps gps gps
#
# Expected:
#
# you're welcome.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.252 	 BLEU: 9.356267808636415
#
#
# Reference: papa_johns is closer at town_and_country_distance.
# Hypothesis: yes, it is at mandarin_roots_address.
#
#
#
#
# Reference: i am setting a new meeting in your calendar for today at 1 pm with hr to go over the budget.
# Hypothesis: okay, i meeting scheduled meeting for budget at 6 pm with hr.
#
#
#
#
# Reference: no problem
# Hypothesis: you're welcome!
#
#
#
#
# Reference: the_clement_hotel is jing_jing_distance away.
# Hypothesis: there is a the_clement_hotel at pizza_my_heart_address.
#
#
#
#
# Reference: which city would you like to find out if it's snowing in?
# Hypothesis: what city are you wanting to know if it will snow?
#
#
#
# EPOCH 22
# ___________________________________________________________________
#
#  Training Loss: 1436.33 	 Token-level Accuracy: 0.470
#
# ***********************************************************
# Input:
#
# what's the forecast for today
#
# Output:
#
# what city do like want the forecast forecast? for
#
# Expected:
#
# what city can i give you the forecast from?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.253 	 BLEU: 9.718056840176432
#
#
# Reference: sorry, i didn't unk which address would you like me to give you. would you prefer to go at safeway or at trader_joes?
# Hypothesis: safeway is at safeway.
#
#
#
#
# Reference: you have 2 dinners on your schedule. one on dinner_date at 6 pm with your dinner_party and one on dinner_date at 7 pm with your dinner_party.
# Hypothesis: you have dinner dinner on tennis_activity_date with dinner_party, and one on tennis_activity_date with your dinner_party.
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you are welcome
#
#
#
#
# Reference: over the next 7 days the days with the highest temperature will be wednesday and friday with a high of 90f.
# Hypothesis: in will be 100f on monday, tuesday, wednesday will be 70-80f, thursday, friday, and sunday.
#
#
#
#
# Reference: you live at home_poi_type_address.
# Hypothesis: your home_poi_type is at home_poi_type_address.
#
#
#
# EPOCH 23
# ___________________________________________________________________
#
#  Training Loss: 1437.29 	 Token-level Accuracy: 0.461
#
# ***********************************************************
# Input:
#
# schedule a 6 pm meeting with my boss to go over the quarterly report on tuesday.
#
# Output:
#
# scheduling a reminder for your meeting at 6 pm on the tuesday with the.
#
# Expected:
#
# okay, scheduling a meeting for 6 pm on tuesday with your boss to go over the quarterly report.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.255 	 BLEU: 9.05662211645943
#
#
# Reference: what city should i check the temperature for?
# Hypothesis: what city are you asking about?
#
#
#
#
# Reference: it will be hot on sunday in inglewood.
# Hypothesis: it will not be overcast in inglewood this weekend.
#
#
#
#
# Reference: comfort_inn route is reporting a 76_traffic_info. do you still want to go there?
# Hypothesis: the best route to it's not. it's palo_alto_garage_r_distance away and there is a valero_traffic_info
#
#
#
#
# Reference: you're very welcome.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: for what city would you like me to check tomorrow's weather for?
# Hypothesis: what city do you want the weather for?
#
#
#
# EPOCH 24
# ___________________________________________________________________
#
#  Training Loss: 1438.12 	 Token-level Accuracy: 0.457
#
# ***********************************************************
# Input:
#
# give me directions to the nearest palo_alto_garage_r_poi_type * palo_alto_garage_r is the nearest at panda_express_distance away. you will find it at palo_alto_garage_r_address * thank you very much car! please bring me there through a quick route * the quickest route has home_traffic_info. is that going to do? * yes sounds good.
#
# Output:
#
# you'm welcome!
#
# Expected:
#
# navigation set. anything else?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.255 	 BLEU: 10.161272744921185
#
#
# Reference: we are safeway_distance away from safeway with mandarin_roots_traffic_info on our way and safeway_distance away from trader_joes with the_westin_traffic_info: where would you like to go?
# Hypothesis: there is a safeway the_westin_distance away.
#
#
#
#
# Reference: navigation is set. drive carefully, and enjoy.
# Hypothesis: you're welcome, the info on your screen, drive carefully!
#
#
#
#
# Reference: where should i check the forecast for rain?
# Hypothesis: what city would you like me to check if it's going to rain?
#
#
#
#
# Reference: anytime
# Hypothesis: you're welcome.
#
#
#
#
# Reference: the nearest chinese unk is panda_express at panda_express_address.
# Hypothesis: the nearest jacks_house_distance is jacks_house_distance away.
#
#
#
# New best bleu score! 10.161272744921185
# EPOCH 25
# ___________________________________________________________________
#
#  Training Loss: 1437.53 	 Token-level Accuracy: 0.460
#
# ***********************************************************
# Input:
#
# schedule tennis for 10am on the tenth with tom * setting reminder for tennis at 10 am on the tenth with tom. * thanks.
#
# Output:
#
# my pleasure.. a
#
# Expected:
#
# my pleasure.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.259 	 BLEU: 8.612975767946951
#
#
# Reference: dish_parking has dish_parking_traffic_info and is the only local one, is it okay?
# Hypothesis: there is jills_house_traffic_info on the route but i have that all still.
#
#
#
#
# Reference: for what location do you want tomorrow's forecast?
# Hypothesis: what city do you want the weather for?
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome, have a great day.
#
#
#
#
# Reference: what city do you want to know the 7 day forecast for?
# Hypothesis: what city do you want the weather for?
#
#
#
#
# Reference: yes, menlo_park is predicted to be misty today.
# Hypothesis: no, it's not gonna be misty in menlo_park
#
#
#
# EPOCH 26
# ___________________________________________________________________
#
#  Training Loss: 1435.00 	 Token-level Accuracy: 0.478
#
# ***********************************************************
# Input:
#
# please add my optometrist appointment to my schedule for august 3rd.
#
# Output:
#
# what, what would day would would like that set the for?
#
# Expected:
#
# okay great, what time would you like to set it for?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.256 	 BLEU: 10.275082161114174
#
#
# Reference: palo_alto_medical_foundation and stanford_express_care are close.
# Hypothesis: sigona_farmers_market_address have a sigona_farmers_market_poi_type sigona_farmers_market_poi_type.
#
#
#
#
# Reference: goodbye.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome p.f._changs_address
#
#
#
#
# Reference: there is whole_foods_traffic_info on the way to jill's house.
# Hypothesis: there is trader_joes_traffic_info on the route to palo_alto_medical_foundation.
#
#
#
#
# Reference: you're welcome.
# Hypothesis: you're welcome!
#
#
#
# New best bleu score! 10.275082161114174
# EPOCH 27
# ___________________________________________________________________
#
#  Training Loss: 1435.14 	 Token-level Accuracy: 0.479
#
# ***********************************************************
# Input:
#
# give me directions to the nearest mall * the nearest mall is town_and_country. it is on town_and_country_address * how far is it and is there any traffic?
#
# Output:
#
# town_and_country is located away at town_and_country_traffic_info. i the plot set route
#
# Expected:
#
# town_and_country is town_and_country_distance away with town_and_country_traffic_info, should i plot a route?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.252 	 BLEU: 9.987440776140424
#
#
# Reference: what day and time should i set an appointment to unk the conference room?
# Hypothesis: what day and time meeting i meeting set meeting?
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you are welcome.
#
#
#
#
# Reference: you're welcome, glad to help.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: you're very welcome!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: pizza_hut is the quickest. navigating to pizza_hut_address. there is round_table_traffic_info on the route.
# Hypothesis: happy to help
#
#
#
# EPOCH 28
# ___________________________________________________________________
#
#  Training Loss: 1437.11 	 Token-level Accuracy: 0.460
#
# ***********************************************************
# Input:
#
# what day is my opdinner_partyetrist appointment and with who? * your opdinner_partyetrist appointment is on optennis_activity_partyetrist_appointment_date with your optennis_activity_partyetrist_appointment_party * okay wonderful, thanks so much! * you're welcome! the appointment starts at optennis_activity_partyetrist_appointment_time also. * thank you
#
# Output:
#
# you are welcome
#
# Expected:
#
# you are welcome
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.254 	 BLEU: 8.469811717218994
#
#
# Reference: plotting route to chevron_address, chevron_distance away with jing_jing_traffic_info
# Hypothesis: there is jills_house_traffic_info on our way, i sent the route on your screen
#
#
#
#
# Reference: the low temperature for menlo_park on monday is 90f with a high of 100f, it will be unk warm
# Hypothesis: it will be monday monday monday monday and monday on monday and 20-40f on monday, monday on monday, clear on monday, clear on monday, clear on monday, clear on monday, windy on monday, windy on monday, windy on monday, windy on friday, 20-40f on saturday, and clear on sunday
#
#
#
#
# Reference: what city do you want to hear thursday's weather for?
# Hypothesis: what city are you inquiring about?
#
#
#
#
# Reference: it will not be cloudy in san_francisco this week.
# Hypothesis: it will not be cloudy in san_francisco this week.
#
#
#
#
# Reference: i will set a reminder for an optometrist appointment at 9 am on the 6th of this month with your brother attending as well.
# Hypothesis: okay, i am scheduling a optometrist appointment with your for for the month at month at 10 am.
#
#
#
# EPOCH 29
# ___________________________________________________________________
#
#  Training Loss: 1435.64 	 Token-level Accuracy: 0.475
#
# ***********************************************************
# Input:
#
# i need a route to a shell_poi_type and avoid teavana_traffic_info. * shell is the only gas but there is teavana_traffic_info. * we're going to run out of gas, set the gps to go there anyway, thank you!
#
# Output:
#
# you did, you info is on your map. the're welcome!
#
# Expected:
#
# i did, the info are on your map, you're welcome!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.247 	 BLEU: 9.162111825262807
#
#
# Reference: what days are you interested in?
# Hypothesis: what day are you interested in new_york weather the weather for?
#
#
#
#
# Reference: there is a chef_chu's_traffic_info but i sent on your screen another route that should allow you to reach there fast enough
# Hypothesis: setting navigation to mandarin_roots.
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you are welcome
#
#
#
#
# Reference: your next swimming_activity is at swimming_activity_time with your swimming_activity_party on swimming_activity_date.
# Hypothesis: your next swimming_activity is scheduled for taking_medicine_date at dentist_appointment_time. taking_medicine_date with swimming_activity_party and the other is on taking_medicine_date at taking_medicine_time with swimming_activity_party.
#
#
#
#
# Reference: anytime!
# Hypothesis: you're welcome!
#
#
#
# EPOCH 30
# ___________________________________________________________________
#
#  Training Loss: 1435.49 	 Token-level Accuracy: 0.476
#
# ***********************************************************
# Input:
#
# directions to the nearest coffee shop * the nearest coffee shop is starbucks on starbucks_address which is starbucks_distance away and there is starbucks_traffic_info. * thanks for the information.
#
# Output:
#
# you'm here to serve. assist you.
#
# Expected:
#
# no problem, i'm here to assist you!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.258 	 BLEU: 8.993599212449972
#
#
# Reference: we're starbucks_distance away unk trader_joes and there is starbucks_traffic_info on our way
# Hypothesis: whole_foods is stanford_childrens_health_distance away.
#
#
#
#
# Reference: there are no nearby starbucks, but there are 3 other coffee places nearby.
# Hypothesis: there is a starbucks nearby.
#
#
#
#
# Reference: what city should i check for snow?
# Hypothesis: what city do you want to know if it will snow?
#
#
#
#
# Reference: you're welcome, happy i could help.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: your tennis_activity is on dentist_appointment_date at 11am.
# Hypothesis: your tennis tennis is dentist_appointment_date at football_activity_time.
#
#
#
# EPOCH 31
# ___________________________________________________________________
#
#  Training Loss: 1432.27 	 Token-level Accuracy: 0.499
#
# ***********************************************************
# Input:
#
# put my optometrist appointment in my calendar * okay, what time is your optometrist appointment? *
#
# Output:
#
# what time is your appointment? appointment??
#
# Expected:
#
# what date and time is your appointment?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.245 	 BLEU: 9.031148031126612
#
#
# Reference: you're very welcome!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: gps set. anything else?
# Hypothesis: the address is philz_address, philz_address there is palo_alto_garage_r_traffic_info on our way, i sent the info on your screen
#
#
#
#
# Reference: here is a route to starbucks, 5677_southwest_4th_street_distance away.
# Hypothesis: the nearest civic_center_garage_poi_type is civic_center_garage_distance away.
#
#
#
#
# Reference: not a problem.
# Hypothesis: you are welcome
#
#
#
#
# Reference: happy to help
# Hypothesis: you are welcome driver
#
#
#
# EPOCH 32
# ___________________________________________________________________
#
#  Training Loss: 1433.29 	 Token-level Accuracy: 0.489
#
# ***********************************************************
# Input:
#
# what's it going to be like in san_jose
#
# Output:
#
# what city would you like the weather for?
#
# Expected:
#
# today there is frost in san_jose, with a high of 60f and a low of 40f. tomorrow will be high 50f and low 30f.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.245 	 BLEU: 9.57526349810256
#
#
# ...
#
#
#
#
# Reference: you are welcome.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: setting directions to coupa, located home_distance away at coupa_address
# Hypothesis: i sent the info on your screen, drive carefully!
#
#
#
# EPOCH 38
# ___________________________________________________________________
#
#  Training Loss: 1431.72 	 Token-level Accuracy: 0.500
#
# ***********************************************************
# Input:
#
# schedule a yoga activity with tom on the 8th at 2pm. * okay, scheduling a yoga activity with tom for the 8th at 2pm. * thanks!
#
# Output:
#
# you problem. you
#
# Expected:
#
# my pleasure.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.248 	 BLEU: 9.101568807748809
#
#
# Reference: of course.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: it will be between 80-100f in grand_rapids this weekend.
# Hypothesis: the temperature in grand_rapids will be between 80-100f monday and between 70-80f on monday and 60-70f on tuesday.
#
#
#
#
# Reference: jing_jing is 1 mile away at jing_jing_addressive. we shouldn't be long in getting there.
# Hypothesis: p.f._changs is located at ravenswood_shopping_center_address. setting ravenswood_shopping_center_address now.
#
#
#
#
# Reference: what city do you need to know if it will be hot?
# Hypothesis: which location do you want the weather for?
#
#
#
#
# Reference: there is a car collision reported on the route to cafe_venetia.
# Hypothesis: setting is starbucks_distance away without any traffic.
#
#
#
# EPOCH 39
# ___________________________________________________________________
#
#  Training Loss: 1429.56 	 Token-level Accuracy: 0.514
#
# ***********************************************************
# Input:
#
# find me a route with pizza_my_heart_traffic_info to the stanford_express_care_poi_type. * the nearest stanford_express_care_poi_type is stanford_express_care at stanford_express_care_address. * give me the address and the fastest route there
#
# Output:
#
# stanford_express_care is at coupa_address.
#
# Expected:
#
# stanford_express_care is at stanford_express_care_address.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.241 	 BLEU: 9.5175639592958
#
#
# Reference: you are welcome.
# Hypothesis: no problem
#
#
#
#
# Reference: no, there is not a blizzard in new_york right now.
# Hypothesis: there is a blizzard in the forecast for new_york right now.
#
#
#
#
# Reference: currently in san_mateo it is cloudy with a low of 30f and a high of 40f
# Hypothesis: in san_mateo, it will rain monday and sunday san_mateo.
#
#
#
#
# Reference: happy to help.
# Hypothesis: you're welcome, have a great day.
#
#
#
#
# Reference: jill lives at jills_house_address.
# Hypothesis: your friend jack is trader_joes_address trader_joes_address.
#
#
#
# EPOCH 40
# ___________________________________________________________________
#
#  Training Loss: 1429.96 	 Token-level Accuracy: 0.513
#
# ***********************************************************
# Input:
#
# where can i go shopping? * stanford_shopping_center is stanford_shopping_center_distance away. * is that the closest stanford_shopping_center_poi_type to my location? * yes, stanford_shopping_center is the closest. * what is the address? * stanford_shopping_center is stanford_shopping_center_distance away at stanford_shopping_center_address. please note there is a road block reported nearby. * oh okay let's start the route now then please.
#
# Output:
#
# setting sent the note note your screen. drive please,
#
# Expected:
#
# i sent the info on your screen, drive carefully!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.240 	 BLEU: 8.777550773921712
#
#
# Reference: your yoga_activity_date yoga_activity with your yoga_activity_party is at 9 am.
# Hypothesis: your yoga_activity is scheduled for yoga_activity_date at yoga_activity_time with yoga_activity_party.
#
#
#
#
# Reference: no problem
# Hypothesis: you are very welcome
#
#
#
#
# Reference: okay, setting a reminder for your doctor's appointment at 2pm on monday the 1st with marie.
# Hypothesis: okay, scheduling a doctor appointment with marie on the 1st at 2pm.
#
#
#
#
# Reference: anytime
# Hypothesis: you're welcome!
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you're welcome; drive safely.
#
#
#
# EPOCH 41
# ___________________________________________________________________
#
#  Training Loss: 1430.06 	 Token-level Accuracy: 0.512
#
# ***********************************************************
# Input:
#
# what palo_alto_medical_foundation_poi_types are here?
#
# Output:
#
# there is starbucks_distance away
#
# Expected:
#
# palo_alto_medical_foundation is philz_distance away.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.240 	 BLEU: 7.877441307393038
#
#
# Reference: i'm here to serve.
# Hypothesis: you are welcome.
#
#
#
#
# Reference: you're very welcome.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: no problem, have a good day.
# Hypothesis: you're welcome
#
#
#
#
# Reference: you are welcome.
# Hypothesis: happy to help
#
#
#
#
# Reference: sure! do you want me to schedule it for tomorrow?
# Hypothesis: okay, scheduling a yoga activity with your for for activity at 10am for the week.
#
#
#
# EPOCH 42
# ___________________________________________________________________
#
#  Training Loss: 1429.94 	 Token-level Accuracy: 0.514
#
# ***********************************************************
# Input:
#
# what is the weather like in boston * what day do you want to know about? * i want to know if it will be windy in boston this weekend.
#
# Output:
#
# you will boston windy boston boston and boston.
#
# Expected:
#
# it will be windy on thursday in boston.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.238 	 BLEU: 8.795585989941726
#
#
# Reference: there is no snow forecasted for chicago this week.
# Hypothesis: it will not snow in chicago this week.
#
#
#
#
# Reference: the nearest coffee place is cafe_venetia at cafe_venetia_address
# Hypothesis: the nearest barista is coupa_distance away.
#
#
#
#
# Reference: in the next week in san_francisco it will be dry on monday, raining on tuesday, hail on wednesday and thursday, hot on friday, overcast on saturday, frost on sunday
# Hypothesis: in san_francisco, it will be stormy on monday, tuesday, and stormy on tuesday, raining on wednesday, hot on thursday, and stormy on saturday, and stormy on sunday.
#
#
#
#
# Reference: there is no starbucks in the area, i'm sorry.
# Hypothesis: there is no starbucks nearby.
#
#
#
#
# Reference: avoiding topanga_mall_traffic_info on the way to jing_jing.
# Hypothesis: i have a route with a longer route for you.
#
#
#
# EPOCH 43
# ___________________________________________________________________
#
#  Training Loss: 1433.06 	 Token-level Accuracy: 0.494
#
# ***********************************************************
# Input:
#
# is it going to snow in the next 7 days
#
# Output:
#
# what what would you you like to know about the snow forecast for? for? what city?
#
# Expected:
#
# snow is in the predictions for several cities, which one would you like me to tell you about?
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.252 	 BLEU: 9.314320243552151
#
#
# Reference: no problem.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: i sent its position on your screen, drive carefully!
# Hypothesis: i sent the route on your screen, drive carefully!
#
#
#
#
# Reference: you're welcome
# Hypothesis: i have a meetings meetings.
#
#
#
#
# Reference: stanford_shopping_center is only whole_foods_distance away and town_and_country is 1 mile away.
# Hypothesis: palo alto is located at pizza_chicago_address.
#
#
#
#
# Reference: the info are on your screen and you're welcome!
# Hypothesis: i're welcome!
#
#
#
# EPOCH 44
# ___________________________________________________________________
#
#  Training Loss: 1427.41 	 Token-level Accuracy: 0.530
#
# ***********************************************************
# Input:
#
# navigate to the nearest place to get coffee * palo_alto_cafe is the nearest place to get coffee at palo_alto_cafe_distance away at palo_alto_cafe_addressive. * thanks.
#
# Output:
#
# palo_alto_cafe are welcome.
#
# Expected:
#
# you're welcome.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.248 	 BLEU: 9.79606296773259
#
#
# Reference: you're welcome, happy i could help.
# Hypothesis: you are welcome.
#
#
#
#
# Reference: your next yoga class is at dentist_appointment_time on dentist_date.
# Hypothesis: your next yoga_activity is on dentist_appointment_date at optometrist_appointment_time.
#
#
#
#
# Reference: glad to be of service.
# Hypothesis: no problem
#
#
#
#
# Reference: philz is 5672_barringer_street_distance away at philz_addressnue. anything else?
# Hypothesis: philz is at philz_address.
#
#
#
#
# Reference: it will not drizzle in oakland next week.
# Hypothesis: it should not be in in in in in next week week.
#
#
#
# EPOCH 45
# ___________________________________________________________________
#
#  Training Loss: 1432.41 	 Token-level Accuracy: 0.496
#
# ***********************************************************
# Input:
#
# what time is my tennis_activity and who is attending? * you have two tennis activities scheduled on different dates. both are at tennis_activity_time with your tennis_activity_party. would you like to know the dates? * yes, that would be helpful. * one is on tennis_activity_date and one is on tennis_activity_date. * thanks!
#
# Output:
#
# you pleasure welcome...
#
# Expected:
#
# you're welcome.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.240 	 BLEU: 9.17737245576415
#
#
# Reference: okay, i've got it scheduled for you. anything else?
# Hypothesis: okay, scheduling a conference with the vice president for the 6th of this month at 4 pm.
#
#
#
#
# Reference: you're welcome!
# Hypothesis: you are very welcome
#
#
#
#
# Reference: setting reminder for yoga activity at 11 am on the 4th with martha.
# Hypothesis: okay, scheduling a yoga activity with martha for the at the am.
#
#
#
#
# Reference: stanford_shopping_center and town_and_country are both near.
# Hypothesis: stanford_shopping_center is located at. which is you want to you?
#
#
#
#
# Reference: it will be windy with a low of 90f and a high of 100f in oakland today.
# Hypothesis: in oakland it will be between 80-100f,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, and,,,,,,,,,,,,,,,,,,,,,, and,,,,,,,,,,,,,,,,,,, and,,,,,,,,,,,,,,,
#
#
#
# EPOCH 46
# ___________________________________________________________________
#
#  Training Loss: 1432.06 	 Token-level Accuracy: 0.498
#
# ***********************************************************
# Input:
#
# what is the address of the local stanford_express_care_poi_type?
#
# Output:
#
# the is at.
#
# Expected:
#
# stanford_express_care is at stanford_express_care_address.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.242 	 BLEU: 8.976159485206574
#
#
# Reference: i sent the info on your screen, drive carefully!
# Hypothesis: gps set for have a great day.
#
#
#
#
# Reference: new_york is supposed to be unk with a chance of rain on saturday with the highs in the 90s and lows in the 20s.
# Hypothesis: what time period are you interested in?
#
#
#
#
# Reference: happy to help
# Hypothesis: you are welcome
#
#
#
#
# Reference: no problem.
# Hypothesis: no problem.
#
#
#
#
# Reference: what city are you inquiring about?
# Hypothesis: what city are you in?
#
#
#
# EPOCH 47
# ___________________________________________________________________
#
#  Training Loss: 1428.90 	 Token-level Accuracy: 0.521
#
# ***********************************************************
# Input:
#
# i need to know the agenda for my meeting as well as who is attending and the location. * the purpose of your meeting is to go over the budget, your meeting_party will be in attendance. * okay, thank you. * you're welcome. also, the location for the meeting is meeting_room. * thank you.
#
# Output:
#
# you,
#
# Expected:
#
# no problem
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.247 	 BLEU: 9.35559979632146
#
#
# Reference: happy to help.
# Hypothesis: you're welcome, glad i could help.
#
#
#
#
# Reference: i sent the info on your screen, you're welcome!
# Hypothesis: you're welcome!
#
#
#
#
# Reference: okay, please tell me which day you would like me to schedule.
# Hypothesis: what time should i schedule the appointment for?
#
#
#
#
# Reference: setting gps to avoid any shell_traffic_info. your route is now set.
# Hypothesis: the route to route has chef_chu's_traffic_info.
#
#
#
#
# Reference: we are pizza_hut_distance away from safeway: do you want me to send you its address on screen?
# Hypothesis: the nearest valero_poi_type is safeway at valero_address.
#
#
#
# EPOCH 48
# ___________________________________________________________________
#
#  Training Loss: 1431.73 	 Token-level Accuracy: 0.501
#
# ***********************************************************
# Input:
#
# get me the address to a stanford_childrens_health_poi_type that is no more than trader_joes_distance away. * there are no stanford_childrens_health_poi_types within trader_joes_distance. * what is the stanford_childrens_health_poi_type nearest to me now then? * stanford childrens stanford_childrens_health_poi_type is stanford_childrens_health_distance away through stanford_childrens_health_traffic_info. it is located at stanford_childrens_health_address. * please pick a route to avoid all midtown_shopping_center_traffic_info and let's go there
#
# Output:
#
# i sent stanford_childrens_health_distance info,, there should, it carefully.
#
# Expected:
#
# i sent the info on your screen, drive carefully!
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.245 	 BLEU: 8.479879479850426
#
#
# Reference: taking you there on the shortest distance.
# Hypothesis: there is to safeway route to safeway.
#
#
#
#
# Reference: what can i tell you about this week's weather in new_york?
# Hypothesis: what days are you interested in?
#
#
#
#
# Reference: you're welcome, stay safe.
# Hypothesis: you're welcome!
#
#
#
#
# Reference: your next tennis_activity is tennis_activity_date at tennis_activity_time with your tennis_activity_party.
# Hypothesis: your tennis_activity is on tennis_activity_date at opfootball_activity_partyetrist_appointment_time.
#
#
#
#
# Reference: glad to be of service.
# Hypothesis: you have no
#
#
#
# EPOCH 49
# ___________________________________________________________________
#
#  Training Loss: 1432.22 	 Token-level Accuracy: 0.498
#
# ***********************************************************
# Input:
#
# is it gonna drizzle in manhattan during the next seven days?
#
# Output:
#
# there tuesday there exeter the forcast predicts drizzle
#
# Expected:
#
# on friday in manhattan the forcast predicts it will drizzle.
# __________________________________________________________________________________________
# Evaluating on dev set...
#  Token-level Accuracy: 0.246 	 BLEU: 9.673889763955282
#
#
# Reference: setting meeting at 2pm on august 3rd with sales team to discuss the merger.
# Hypothesis: i have scheduled a meeting at at at at. with with to discuss the. merger
#
#
#
#
# Reference: what day and time should i set an appointment to unk the conference room?
# Hypothesis: what day and time do you want to set the reminder for?
#
#
#
#
# Reference: you are welcome.
# Hypothesis: gps set to quickest route to..
#
#
#
#
# Reference: no problem.
# Hypothesis: you're welcome.
#
#
#
#
# Reference: you are welcome human
# Hypothesis: you are welcome.
#
#
#
# Evaluating best model on test set...
#  Token-level Accuracy: 0.227 	 BLEU: 7.78914010778275
# Saving model to models/...

# %%
dataset.test.device = torch.device("cpu")
with open(model_save_dir / "dataset.pkl", "wb") as f:
    pickle.dump(dataset.test, f)

# %%
dataset.test.kb[0].device
# Out:
# device(type='cpu')
